# %%
# SALES ANALYSIS REPORT #

# %%
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv("C:\priya\Project 1 - Sales Data Analysis\Copy of  Sales Data .csv")
sales.head()
# to load the csv file from the pc
# to display the head of the data
# Out:
#    Column1  Order ID               Product  Quantity Ordered Price Each  \
# 0        0    295665    Macbook Pro Laptop                 1  $1,700.00
# 1        1    295666    LG Washing Machine                 1    $600.00
# 2        2    295667  USB-C Charging Cable                 1     $11.95
# 3        3    295668      27in FHD Monitor                 1    $149.99
# 4        4    295669  USB-C Charging Cable                 1     $11.95
#
#          Order Date  Order Date.1  Order Time  \
# 0   12/30/2019 0:01    43829.0006     44444.0
# 1   12/29/2019 7:03    43828.2937     29375.0
# 2  12/12/2019 18:21    43811.7645     33333.0
# 3  12/22/2019 15:13    43821.6340     77778.0
# 4  12/18/2019 12:38    43817.5263     88889.0
#
#                          Purchase Address  Month Month Name      Sales  \
# 0  136 Church St, New York City, NY 10001     12        DEC  $1,700.00
# 1     562 2nd St, New York City, NY 10001     12        DEC    $600.00
# ...

# %%
sales.tail()
# to display the tail of the data
# Out:
#         Column1  Order ID                 Product  Quantity Ordered  \
# 185945    13617    222905  AAA Batteries (4-pack)                 1
# 185946    13618    222906        27in FHD Monitor                 1
# 185947    13619    222907    USB-C Charging Cable                 1
# 185948    13620    222908    USB-C Charging Cable                 1
# 185949    13621    222909  AAA Batteries (4-pack)                 1
#
#        Price Each       Order Date  Order Date.1  Order Time  \
# 185945      $2.99   6/7/2019 19:02     43623.793     55556.0
# 185946    $149.99   6/1/2019 19:29     43617.811     55556.0
# 185947     $11.95  6/22/2019 18:57     43638.789     33333.0
# 185948     $11.95  6/26/2019 18:35     43642.774     55556.0
# 185949      $2.99  6/25/2019 14:33     43641.606     60625.0
#
#                              Purchase Address  Month Month Name    Sales  \
# 185945          795 Pine St, Boston, MA 02215      6       JUNE    $2.99
# ...

# %%
pd.set_option('display.max_rows',100)
sales
#to display 'n' rows
# Out:
#         Column1  Order ID                 Product  Quantity Ordered  \
# 0             0    295665      Macbook Pro Laptop                 1
# 1             1    295666      LG Washing Machine                 1
# 2             2    295667    USB-C Charging Cable                 1
# 3             3    295668        27in FHD Monitor                 1
# 4             4    295669    USB-C Charging Cable                 1
# ...         ...       ...                     ...               ...
# 185945    13617    222905  AAA Batteries (4-pack)                 1
# 185946    13618    222906        27in FHD Monitor                 1
# 185947    13619    222907    USB-C Charging Cable                 1
# 185948    13620    222908    USB-C Charging Cable                 1
# 185949    13621    222909  AAA Batteries (4-pack)                 1
#
#        Price Each        Order Date  Order Date.1  Order Time  \
# 0       $1,700.00   12/30/2019 0:01    43829.0006     44444.0
# ...

# %%
sales.index
# to display the index of the data
# Out:
# RangeIndex(start=0, stop=185950, step=1)

# %%
sales.columns
#to display the columns sttributes of the data
# Out:
# Index(['Column1', 'Order ID', 'Product', 'Quantity Ordered', 'Price Each',
#        'Order Date', 'Order Date.1', 'Order Time', 'Purchase Address', 'Month',
#        'Month Name', 'Sales', 'City', 'Country', 'Hour', 'Profit'],
#       dtype='object')
